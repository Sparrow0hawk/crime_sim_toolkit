# %% [markdown]
# <a href="https://colab.research.google.com/github/Sparrow0hawk/crime_sim_toolkit/blob/develop-CSS-match/data_manipulation/CrimeDes_toCSS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Map Crime Descriptions to Crime Severity Scores

# %%
# !wget -O cssdatatool.xls https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/crimeandjustice/datasets/crimeseverityscoreexperimentalstatistics/current/cssdatatool.xls
# Out:
# --2019-09-09 08:16:22--  https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/crimeandjustice/datasets/crimeseverityscoreexperimentalstatistics/current/cssdatatool.xls
# Resolving www.ons.gov.uk (www.ons.gov.uk)... 104.20.60.76, 104.20.61.76, 2606:4700:10::6814:3d4c, ...
# Connecting to www.ons.gov.uk (www.ons.gov.uk)|104.20.60.76|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/vnd.ms-excel]
# Saving to: ‘cssdatatool.xls’
#
# cssdatatool.xls         [   <=>              ]   8.96M  14.9MB/s    in 0.6s
#
# 2019-09-09 08:16:24 (14.9 MB/s) - ‘cssdatatool.xls’ saved [9394176]

# %%
# !ls
# Out:
# cssdatatool.xls  sample_data

# %%
import pandas as pd
import numpy as np

# %%
crime_des_data = pd.read_csv('https://raw.githubusercontent.com/Sparrow0hawk/crime_sim_toolkit/develop-CSS-match/crime_sim_toolkit/src/simple_policeuk_perc_offence.csv', index_col=0)

CSS_score_xls = pd.ExcelFile('cssdatatool.xls')

# %%
crime_des_data.Offence_Description = crime_des_data.Offence_Description.str.lower()

crime_des_data.Offence_Code = crime_des_data.Offence_Code.astype(str)

# %%
weights = CSS_score_xls.parse('List of weights', skiprows=4)

# %%
weights.head()
# Out:
#                       Unnamed: 0   Unnamed: 1   Offence       Weight
# 0                            NaN          NaN       NaN          NaN
# 1  VICTIM BASED CRIME - VIOLENCE          NaN       NaN          NaN
# 2                            NaN          NaN       NaN          NaN
# 3                            NaN  1, 4.1/2/10  Homicide  7973.393423
# 4                            NaN          NaN       NaN          NaN

# %%
weights = weights.iloc[:,1:]

weights.head()
# Out:
#     Unnamed: 1   Offence       Weight
# 0          NaN       NaN          NaN
# 1          NaN       NaN          NaN
# 2          NaN       NaN          NaN
# 3  1, 4.1/2/10  Homicide  7973.393423
# 4          NaN       NaN          NaN

# %%
weights.columns = ['Offence_cd','Offence_Description','Weight']

weights.Offence_Description = weights.Offence_Description.str.lower()

weights.Offence_cd = weights.Offence_cd.astype(str)

weights.dropna(inplace=True)

# %%
weights.head()
# Out:
#     Offence_cd                                Offence_Description       Weight
# 3  1, 4.1/2/10                                           homicide  7973.393423
# 5          4.4  causing death or serious injury by dangerous d...  1022.814458
# 6          4.6  causing death by careless driving when under t...  1512.002797
# 7          4.8  causing death by careless or inconsiderate dri...   111.361322
# 8      4.4/6/8     causing death by dangerous or careless driving   690.720426

# %%
weights.Offence_Description.isin(crime_des_data.Offence_Description.unique().tolist()).sum()
# Out:
# 92

# %%
weights[weights.Offence_Description.isin(crime_des_data.Offence_Description.unique().tolist())]
# Out:
#       Offence_cd  ...       Weight
# 3    1, 4.1/2/10  ...  7973.393423
# 5            4.4  ...  1022.814458
# 7            4.8  ...   111.361322
# 10          37.1  ...   532.416667
# 12             2  ...  4654.298133
# 18            5D  ...  2034.741860
# 19            5E  ...  1446.982552
# 30            8N  ...   189.153887
# 31            8P  ...   312.906712
# 32            8S  ...   401.424397
# 35            3A  ...  2024.222684
# 36            3B  ...   275.308777
# 38           11A  ...   138.716331
# 40            13  ...   289.815402
# 41            14  ...  1056.409091
# 42            36  ...  1216.814993
# 43           104  ...     7.543806
# 44          105A  ...    13.510542
# 45          105B  ...    30.763236
# 46           106  ...  1069.064103
# 48            8L  ...    36.097530
# 49            8M  ...    37.511298
# 50            8Q  ...    56.349710
# 51            8R  ...    15.138929
# 58           19D  ...  3883.132787
# 59           19E  ...  3225.096476
# 62           19G  ...  3894.781113
# 63           19H  ...  2397.258672
# 70           17A  ...   767.443710
# 71           17B  ...   862.269087
# ..           ...  ...          ...
# 152          58D  ...     5.396708
# 157          58J  ...    14.005599
# 161          92A  ...   512.957359
# 164          92C  ...     9.062219
# 171          10A  ...   616.560089
# 172          10B  ...   412.202395
# 173          10C  ...    52.126097
# 174          10D  ...    53.038239
# 175           81  ...  1287.544413
# 176           90  ...   250.250000
# 180           9A  ...     6.811758
# 181           9B  ...    12.763384
# 183          62A  ...   362.896454
# 186           65  ...   348.482352
# 187           66  ...    72.508733
# 191           15  ...   201.398958
# 192           24  ...   366.020324
# 193           26  ...   201.398958
# 196          33A  ...   135.274869
# 200           54  ...    55.135290
# 203           61  ...   145.800704
# 204          61A  ...   193.686118
# 205           67  ...    97.845581
# 207           69  ...   207.043450
# 209           76  ...   817.437500
# 211           79  ...   168.738460
# 212           80  ...   192.375992
# 214           83  ...     3.304401
# 222           95  ...    12.917192
# 225          802  ...   119.877313
#
# [92 rows x 3 columns]

# %%
crime_des_data[crime_des_data.Offence_Description.str.lower().isin(weights.Offence_Description.str.lower())].Offence_Description.unique().shape
# Out:
# (90,)

# %%
crime_des_data[~crime_des_data.Offence_Description.str.lower().isin(weights.Offence_Description.str.lower())].Offence_Description.unique().shape
# Out:
# (42,)

# %%
crime_des_data[~crime_des_data.Offence_Description.str.lower().isin(weights.Offence_Description.str.lower())].Offence_Description.unique()
# Out:
# array(['fraud offences recorded by action fraud',
#        'aggravated burglary business and community',
#        'aggravated burglary in a building other than a dwelling(outcome only)',
#        'aggravated burglary in a dwelling (outcome only)',
#        'aggravated burglary residential',
#        'attempted burglary business and community',
#        'attempted burglary in a building other than a dwelling (outcome only)',
#        'attempted burglary in a dwelling (outcome only)',
#        'attempted burglary residential',
#        'attempted distraction burglary in a dwelling (outcome only)',
#        'attempted distraction burglary residential',
#        'burglary business and community',
#        'burglary in a building other than a dwelling (outcome only)',
#        'burglary in a dwelling(outcome only)', 'burglary residential',
#        'causing death by careless driving under influence of drink or drugs',
#        'causing death by driving: unlicensed or disqualified or uninsured drivers',
#        'causing or allowing death of child or vulnerable person',
#        'distraction burglary in a dwelling (outcome only)',
#        'distraction burglary residential',
#        'forgery or use of false drug prescription',
#        'fraud, forgery etc associated with vehicle or driver records',
#        'going equipped for stealing, etc',
#        'intentional destruction of a viable unborn child',
#        'interfering with a motor vehicle', 'obscene publications etc',
#        'other notifiable offences',
#        'possession of controlled drugs (cannabis)',
#        'possession of controlled drugs (excl. cannabis)',
#        'profiting from or concealing knowledge of the proceeds of crime',
#        'rape of a female aged 16 and over',
#        'rape of a male aged 16 and over',
#        'sexual activity etc with a person with a mental disorder',
#        'sexual activity involving child under 16',
#        'soliciting for the purposes of prostitution',
#        'theft from vehicle',
#        'theft or unauthorised taking of motor vehicle',
#        'threat or possession with intent to commit criminal damage',
#        'wildlife', 'fraud offences recorded by cifas',
#        'fraud offences recorded by financial fraud action uk',
#        'fraud offences recorded by uk finance'], dtype=object)

# %%
weights[weights.Offence_Description.str.lower().str.contains('burg')]
# Out:
#     Offence_cd                                Offence_Description       Weight
# 106    28, 28A                             burglary in a dwelling   465.381473
# 107        28B                   attempted burglary in a dwelling   465.381473
# 108        28C                 distraction burglary in a dwelling   465.381473
# 109        28D       attempted distraction burglary in a dwelling   465.381473
# 110        28E                             burglary - residential   465.381473
# 111        28F                   attempted burglary - residential   465.381473
# 112        28G                 distraction burglary - residential   465.381473
# 113        28H       attempted distraction burglary - residential   465.381473
# 114         29                  aggravated burglary in a dwelling  2288.669158
# 115        29A                  aggravated burglary - residential  2288.669158
# 116    30, 30A       burglary in a building other than a dwelling   123.018396
# 117        30B  attempted burglary in a building other than a ...   123.018396
# 118        30C                  burglary - business and community   123.018396
# 119        30D        attempted burglary - business and community   123.018396
# 120         31  aggravated burglary in a building other than a...  1849.520062
# 121        31A       aggravated burglary - business and community  1849.520062

# %% [markdown]
# Start constructing dataframe that includes weights matched by either crime code or string match to crime description

# %%
basic_frame = crime_des_data.copy()

basic_frame = basic_frame.drop_duplicates(subset=['Offence_Description'])

basic_frame.shape
# Out:
# (132, 8)

# %%
basic_frame = basic_frame[['Policeuk_Cat', 'Offence_Group', 'Offence_Subgroup',
       'Offence_Description', 'Offence_Code']]

basic_frame.head()
# Out:
#                    Policeuk_Cat  ... Offence_Code
# 0                   Other crime  ...           AF
# 1                   Other crime  ...           80
# 2  Violence and Sexual Offences  ...           71
# 3  Violence and Sexual Offences  ...           73
# 4                      Burglary  ...          31A
#
# [5 rows x 5 columns]

# %%
weights_frame = basic_frame.set_index('Offence_Description').join(weights[weights.Offence_Description.isin(crime_des_data.Offence_Description.unique().tolist())].set_index('Offence_Description')['Weight'])

weights_frame.reset_index(inplace=True)

# %%
weights_frame.head()
# Out:
#                                  Offence_Description  ...      Weight
# 0                     absconding from lawful custody  ...  192.375992
# 1      abuse of children through sexual exploitation  ...  939.264396
# 2      abuse of position of trust of a sexual nature  ...  240.649045
# 3         aggravated burglary business and community  ...         NaN
# 4  aggravated burglary in a building other than a...  ...         NaN
#
# [5 rows x 6 columns]

# %%
weights_frame = weights_frame.set_index('Offence_Code').join(weights[weights.Offence_cd.isin(crime_des_data.Offence_Code.unique().tolist())].set_index('Offence_cd')['Weight'], rsuffix='_cd')

weights_frame.reset_index(inplace=True)

weights_frame.columns = ['Offence_code','Offence_Description','Policeuk_Cat','Offence_Group','Offence_Subgroup','Weight','Weight_cd']

# %%
weights_frame.fillna(0, inplace=True)

weights_frame['Weight'] = weights_frame.apply(lambda x: x['Weight'] + x['Weight_cd'], axis=1)

weights_frame.drop('Weight_cd', axis=1, inplace=True)

weights_frame.head()
# Out:
#      Offence_code  ...       Weight
# 0  1/4.1/4.10/4.2  ...  7973.393423
# 1             104  ...    15.087613
# 2            105A  ...    27.021083
# 3            105B  ...    61.526472
# 4             106  ...  2138.128205
#
# [5 rows x 6 columns]

# %%
# unmatched crime categories 

weights_frame[weights_frame.Weight == 0]
# Out:
#     Offence_code  ... Weight
# 33           28A  ...    0.0
# 43           30A  ...    0.0
# 131           AF  ...    0.0
# 132        CIFAS  ...    0.0
# 133       FFA UK  ...    0.0
# 134   UK Finance  ...    0.0
#
# [6 rows x 6 columns]

# %%
# the two burglary categories are due to shared crime codes which I can explode into individual rows

# we'll hack our way to setting these values

weights_frame[(weights_frame.Offence_Description.str.contains('burg')) & (weights_frame.Weight == 0)]
# Out:
#    Offence_code  ... Weight
# 33          28A  ...    0.0
# 43          30A  ...    0.0
#
# [2 rows x 6 columns]

# %%
# this will set value for offence code 28A
# and will generate a warning

weights_frame.loc[weights_frame.Offence_code == '28A','Weight'] = weights[weights.Offence_cd.str.contains('28A')]['Weight'].tolist()[0]

# %%
# this will set value for offence code 30A

weights_frame.loc[weights_frame.Offence_code == '30A','Weight'] = weights[weights.Offence_cd.str.contains('28A')]['Weight'].tolist()[0]

# %%
# unmatched crime categories 

weights_frame[weights_frame.Weight == 0]
# Out:
#     Offence_code  ... Weight
# 131           AF  ...    0.0
# 132        CIFAS  ...    0.0
# 133       FFA UK  ...    0.0
# 134   UK Finance  ...    0.0
#
# [4 rows x 6 columns]

# %%
# for now we'll just calculate the mean weight of all fraud crimes

weights[weights.Offence_Description.str.contains('fraud')].Weight.mean()
# Out:
# 116.91071432167321

# %%
# this will set value for all remaining 0 weight crimes shown above

weights_frame.loc[weights_frame.Weight == 0,'Weight'] = weights[weights.Offence_Description.str.contains('fraud')].Weight.mean()

# %%
# unmatched crime categories 

weights_frame[weights_frame.Weight == 0]
# Out:
# Empty DataFrame
# Columns: [Offence_code, Offence_Description, Policeuk_Cat, Offence_Group, Offence_Subgroup, Weight]
# Index: []

# %%
weights_frame = weights_frame[['Policeuk_Cat', 'Offence_Group','Offence_Subgroup','Offence_Description','Offence_code', 'Weight']]

# %%
weights_frame
# Out:
#                      Policeuk_Cat  ...       Weight
# 0    Violence and Sexual Offences  ...  7973.393423
# 1    Violence and Sexual Offences  ...    15.087613
# 2    Violence and Sexual Offences  ...    27.021083
# 3    Violence and Sexual Offences  ...    61.526472
# 4    Violence and Sexual Offences  ...  2138.128205
# 5           Possession of Weapons  ...  1233.120179
# 6           Possession of Weapons  ...   824.404789
# 7           Possession of Weapons  ...   104.252194
# 8           Possession of Weapons  ...   106.076478
# 9    Violence and Sexual Offences  ...   277.432663
# 10                  Vehicle Crime  ...     9.314707
# 11   Violence and Sexual Offences  ...   579.630804
# 12   Violence and Sexual Offences  ...  2112.818182
# 13                    Other crime  ...   402.797916
# 14   Violence and Sexual Offences  ...  1534.887421
# 15   Violence and Sexual Offences  ...  1724.538173
# 16   Violence and Sexual Offences  ...  2952.940993
# 17   Violence and Sexual Offences  ...  7766.265573
# 18   Violence and Sexual Offences  ...  6450.192952
# 19   Violence and Sexual Offences  ...  3191.964624
# 20   Violence and Sexual Offences  ...  7789.562227
# 21   Violence and Sexual Offences  ...  4794.517343
# 22   Violence and Sexual Offences  ...  9308.596266
# 23   Violence and Sexual Offences  ...   918.139833
# 24   Violence and Sexual Offences  ...  2423.942728
# 25   Violence and Sexual Offences  ...  1647.437990
# 26   Violence and Sexual Offences  ...  1647.437990
# 27   Violence and Sexual Offences  ...  2109.493274
# 28   Violence and Sexual Offences  ...   726.444970
# 29   Violence and Sexual Offences  ...  2244.738476
# ..                            ...  ...          ...
# 105         Possession of Weapons  ...  2575.088826
# 106                   Other crime  ...     7.259604
# 107                   Other crime  ...     6.608803
# 108                   Other crime  ...   137.282544
# 109  Violence and Sexual Offences  ...   925.898628
# 110  Violence and Sexual Offences  ...  1095.896089
# 111  Violence and Sexual Offences  ...  2053.758707
# 112  Violence and Sexual Offences  ...   103.426042
# 113  Violence and Sexual Offences  ...    79.844004
# 114  Violence and Sexual Offences  ...    72.195060
# 115  Violence and Sexual Offences  ...    75.022596
# 116  Violence and Sexual Offences  ...   378.307774
# 117  Violence and Sexual Offences  ...   625.813424
# 118  Violence and Sexual Offences  ...   112.699419
# 119  Violence and Sexual Offences  ...    30.277857
# 120  Violence and Sexual Offences  ...   802.848794
# 121         Possession of Weapons  ...   500.500000
# 122                         Drugs  ...  1025.914719
# 123                         Drugs  ...    18.124438
# 124                         Drugs  ...     8.082043
# 125                         Drugs  ...     1.770623
# 126                   Other crime  ...    25.834383
# 127                   Other crime  ...   247.854990
# 128                   Other crime  ...   179.249472
# 129                  Public Order  ...    13.623515
# 130                  Public Order  ...    25.526769
# 131                   Other crime  ...   116.910714
# 132                   Other crime  ...   116.910714
# 133                   Other crime  ...   116.910714
# 134                   Other crime  ...   116.910714
#
# [135 rows x 6 columns]
